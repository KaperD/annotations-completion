# %% [markdown]
# # Load usages, save them to pickle file and show stats

# %%
from utils.usage_loader import UsagesLoader
from stats.annotations_stats import Stats
import pickle
from pathlib import Path

# %%
paths = ['/Users/danilbk/Programming/Kotlin/test/intellij-community/project-processing-results/processing/java/annotations/processing/0.0.0']

# %%
usage_loader = UsagesLoader(paths)

# %%
Path("data").mkdir(parents=True, exist_ok=True)
with open('data/usage_loader.pickle', 'wb') as f:
    pickle.dump(usage_loader, f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 Path("data").mkdir(parents=True, exist_ok=True)
#       2 with open('data/usage_loader.pickle', 'wb') as f:
# ----> 3     pickle.dump(usage_loader, f)
#
# KeyboardInterrupt:

# %%
len(usage_loader.load_all())
# Out:
# 574931

# %%
stats = Stats(usage_loader)

# %%
stats.number_of_annotation_by_target()

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(15, 9))
stats.top_i_annotations(10)

# %%
stats.top_i_annotations_by_target(10)

# %%
stats = None
usage_loader = None
