# %%
from models.tree import CatBoost
from models.baseline import Baseline
from utils.usage_loader import initial_feature_names
from utils.encoder import encode_column
from sklearn.utils import shuffle
import numpy as np
import random
from utils.usage_loader import UsagesLoader
from metric.calculate import calculate_and_print
from pathlib import PurePath
from metric.metric import Metric

# %%
usage_loader = UsagesLoader(['community/0.0.0'])

# %%
usages = list(filter(lambda x: 'java.lang.Override' not in x.annotation_name, usage_loader.load_all()))
train_usages = usages
test_usages = []
while len(train_usages) > 100000:
    random_usage = random.choice(train_usages)
    module = '/'.join(PurePath(random_usage.file_path).parts[:3])
    print(module)
    test_usages += list(filter(lambda x: x.file_path.startswith(module), train_usages))
    train_usages = list(filter(lambda x: not x.file_path.startswith(module), train_usages))
    print(len(train_usages))
print(len(train_usages))
print(len(test_usages))
test_usages = shuffle(test_usages, random_state=123)[:200000]
usages = train_usages + test_usages
raw_X = np.array([np.array(usage.features_list, dtype=object) for usage in usages])
X = None
all_new_names = []
for col in range(raw_X.shape[1]):
    new_columns, new_names = encode_column(raw_X[:, col], len(train_usages),
                                           initial_feature_names[col], 100)
    if new_columns is None:
        continue
    all_new_names += new_names
    if X is None:
        X = new_columns
    else:
        X = np.concatenate((X, new_columns), axis=1)
y = np.array([usage.annotation_name for usage in usages])

actual_train_size = len(X) - len(test_usages)
X_train = X[:actual_train_size]
y_train = y[:actual_train_size]
X_test = X[actual_train_size:]
y_test = y[actual_train_size:]
# Out:
# plugins/tasks/tasks-core
# 419516
# plugins/lombok/src
# 417375
# android/android-adb/src
# 417221
# platform/lang-impl/src
# 388037
# platform/vcs-log/impl
# 384362
# platform/external-system-impl/src
# 382082
# java/java-psi-api/src
# 378522
# platform/platform-impl/src
# 355737
# java/idea-ui/src
# 352581
# plugins/maven/src
# 347612
# java/java-impl/src
# 335656
# android/gradle-dsl/src
# 332085
# plugins/kotlin/refIndex
# 330266
# plugins/kotlin/idea
# 308031
# jps/jps-builders/src
# 306574
# android/android/src
# 282822
# plugins/stream-debugger/src
# 282261
# platform/core-impl/src
# 276565
# java/java-impl-inspections/src
# 273368
# platform/vcs-impl/src
# 264289
# platform/editor-ui-api/src
# 262565
# platform/xdebugger-impl/src
# 259932
# java/java-indexing-api/src
# 259650
# plugins/javaFX/src
# 258739
# java/java-psi-impl/src
# 252399
# java/java-analysis-impl/src
# 245583
# platform/util/src
# 235923
# android/profilers-android/src
# 235474
# plugins/svn4idea/src
# 231135
# platform/diff-impl/src
# 226010
# platform/util/ui
# 223488
# plugins/kotlin/analysis-api-providers-ide-impl
# 223426
# platform/platform-tests/testSrc
# 220342
# android/designer/src
# 213130
# plugins/groovy/src
# 209357
# platform/execution-impl/src
# 207221
# android/layout-ui/src
# 207089
# platform/platform-api/src
# 198412
# platform/ide-core-impl/src
# 197673
# platform/testFramework/src
# 194707
# RegExpSupport/src/org
# 194293
# plugins/sh/src
# 193613
# platform/code-style-api/src
# 192074
# platform/util-rt/src
# 191407
# plugins/kotlin/completion
# 188697
# plugins/InspectionGadgets/InspectionGadgetsAnalysis
# 184102
# platform/smRunner/src
# 183306
# plugins/groovy/groovy-psi
# 175486
# plugins/xpath/xpath-lang
# 174470
# platform/analysis-impl/src
# 169225
# android/project-system-gradle-psd/src
# 168300
# platform/xdebugger-api/src
# 167657
# spellchecker/src/com
# 167347
# plugins/IntentionPowerPak/src
# 166820
# plugins/sh/gen
# 165775
# plugins/kotlin/fir
# 162289
# android/adt-ui/src
# 160179
# platform/core-api/src
# 153477
# platform/external-system-api/src
# 152238
# platform/analysis-api/src
# 149042
# java/java-impl-refactorings/src
# 146138
# platform/ide-core/src
# 144339
# java/java-tests/testSrc
# 141245
# platform/editor-ui-ex/src
# 140399
# platform/vfs-impl/src
# 138669
# java/manifest/src
# 138545
# platform/lang-api/src
# 135575
# android/android-lang/gen
# 134238
# plugins/kotlin/project-wizard
# 134132
# platform/structuralsearch/source
# 132763
# plugins/git4idea/src
# 126177
# platform/util/testSrc
# 125591
# plugins/kotlin/j2k
# 124241
# python/python-psi-impl/src
# 115186
# plugins/InspectionGadgets/src
# 113227
# plugins/kotlin/jvm-debugger
# 110661
# platform/projectModel-api/src
# 109600
# plugins/kotlin/performance-tests
# 108421
# plugins/gradle/tooling-extension-impl
# 107775
# plugins/gradle/java
# 106722
# plugins/gradle/tooling-extension-api
# 106327
# platform/indexing-api/src
# 105341
# android/profilers-ui/src
# 104186
# android/android/testSrc
# 99272
# 99272
# 321731

# %%
len(X_train)
# Out:
# 99272

# %%
model = CatBoost(task_type='GPU', early_stopping_rounds=20, verbose=True, iterations=500, learning_rate=0.05)
baseline = Baseline()

calculate_and_print(X_train, X_test, y_train, y_test, baseline)
calculate_and_print(X_train, X_test, y_train, y_test, model)
# Out:
# Baseline
# Count: 200000
# Top 1: 0.61997
# Top 2: 0.764235
# Top 3: 0.78384
# Top 4: 0.79652
# Top 5: 0.80636
# Top1 1: 0.63647
# Mean: 5.839775
# CatBoost
# 0:	learn: 2.1171583	test: 1.6048590	best: 1.6048590 (0)	total: 1.01s	remaining: 8m 24s
# 1:	learn: 1.7725536	test: 1.4503720	best: 1.4503720 (1)	total: 1.91s	remaining: 7m 55s
# 2:	learn: 1.6324830	test: 1.3288597	best: 1.3288597 (2)	total: 2.84s	remaining: 7m 49s
# 3:	learn: 1.5352651	test: 1.2118342	best: 1.2118342 (3)	total: 3.74s	remaining: 7m 43s
# 4:	learn: 1.4787783	test: 1.1862038	best: 1.1862038 (4)	total: 4.6s	remaining: 7m 35s
# 5:	learn: 1.4318220	test: 1.1512910	best: 1.1512910 (5)	total: 5.52s	remaining: 7m 34s
# 6:	learn: 1.3943146	test: 1.1345995	best: 1.1345995 (6)	total: 6.38s	remaining: 7m 29s
# 7:	learn: 1.3617711	test: 1.1162525	best: 1.1162525 (7)	total: 7.24s	remaining: 7m 25s
# 8:	learn: 1.3359176	test: 1.1062280	best: 1.1062280 (8)	total: 8.2s	remaining: 7m 27s
# 9:	learn: 1.3122179	test: 1.0873904	best: 1.0873904 (9)	total: 9.09s	remaining: 7m 25s
# 10:	learn: 1.2893569	test: 1.0772295	best: 1.0772295 (10)	total: 9.9s	remaining: 7m 20s
# 11:	learn: 1.2655148	test: 1.0687824	best: 1.0687824 (11)	total: 10.7s	remaining: 7m 13s
# 12:	learn: 1.2432942	test: 1.0540150	best: 1.0540150 (12)	total: 11.6s	remaining: 7m 14s
# 13:	learn: 1.2265384	test: 1.0491723	best: 1.0491723 (13)	total: 12.4s	remaining: 7m 12s
# 14:	learn: 1.2091360	test: 1.0401645	best: 1.0401645 (14)	total: 13.5s	remaining: 7m 16s
# 15:	learn: 1.1905709	test: 1.0306899	best: 1.0306899 (15)	total: 14.4s	remaining: 7m 15s
# 16:	learn: 1.1750018	test: 1.0180933	best: 1.0180933 (16)	total: 15.3s	remaining: 7m 15s
# 17:	learn: 1.1579907	test: 1.0076613	best: 1.0076613 (17)	total: 16.6s	remaining: 7m 24s
# 18:	learn: 1.1466772	test: 1.0008717	best: 1.0008717 (18)	total: 17.5s	remaining: 7m 22s
# 19:	learn: 1.1339293	test: 0.9936856	best: 0.9936856 (19)	total: 18.6s	remaining: 7m 26s
# 20:	learn: 1.1228265	test: 0.9878894	best: 0.9878894 (20)	total: 19.7s	remaining: 7m 29s
# 21:	learn: 1.1132696	test: 0.9811028	best: 0.9811028 (21)	total: 20.7s	remaining: 7m 30s
# 22:	learn: 1.0986395	test: 0.9715795	best: 0.9715795 (22)	total: 21.8s	remaining: 7m 32s
# 23:	learn: 1.0879561	test: 0.9657276	best: 0.9657276 (23)	total: 22.9s	remaining: 7m 33s
# 24:	learn: 1.0748378	test: 0.9593805	best: 0.9593805 (24)	total: 24s	remaining: 7m 36s
# 25:	learn: 1.0674236	test: 0.9541156	best: 0.9541156 (25)	total: 25s	remaining: 7m 36s
# 26:	learn: 1.0597643	test: 0.9520135	best: 0.9520135 (26)	total: 25.9s	remaining: 7m 33s
# 27:	learn: 1.0502924	test: 0.9463172	best: 0.9463172 (27)	total: 27s	remaining: 7m 34s
# 28:	learn: 1.0414088	test: 0.9403108	best: 0.9403108 (28)	total: 28s	remaining: 7m 35s
# 29:	learn: 1.0352433	test: 0.9381186	best: 0.9381186 (29)	total: 29.1s	remaining: 7m 35s
# 30:	learn: 1.0265199	test: 0.9323692	best: 0.9323692 (30)	total: 30.1s	remaining: 7m 34s
# 31:	learn: 1.0197247	test: 0.9292332	best: 0.9292332 (31)	total: 31.1s	remaining: 7m 34s
# 32:	learn: 1.0116125	test: 0.9260392	best: 0.9260392 (32)	total: 32s	remaining: 7m 32s
# 33:	learn: 1.0050031	test: 0.9234870	best: 0.9234870 (33)	total: 32.9s	remaining: 7m 30s
# 34:	learn: 0.9978074	test: 0.9165502	best: 0.9165502 (34)	total: 33.8s	remaining: 7m 29s
# 35:	learn: 0.9885317	test: 0.9087036	best: 0.9087036 (35)	total: 34.9s	remaining: 7m 29s
# 36:	learn: 0.9819941	test: 0.9053301	best: 0.9053301 (36)	total: 36s	remaining: 7m 30s
# 37:	learn: 0.9759530	test: 0.9057585	best: 0.9053301 (36)	total: 36.9s	remaining: 7m 28s
# 38:	learn: 0.9720535	test: 0.9016090	best: 0.9016090 (38)	total: 37.7s	remaining: 7m 25s
# 39:	learn: 0.9670735	test: 0.8989740	best: 0.8989740 (39)	total: 38.7s	remaining: 7m 25s
# 40:	learn: 0.9605447	test: 0.8941240	best: 0.8941240 (40)	total: 39.9s	remaining: 7m 26s
# 41:	learn: 0.9541527	test: 0.8937466	best: 0.8937466 (41)	total: 40.7s	remaining: 7m 24s
# 42:	learn: 0.9499897	test: 0.8928634	best: 0.8928634 (42)	total: 41.6s	remaining: 7m 22s
# 43:	learn: 0.9467933	test: 0.8902679	best: 0.8902679 (43)	total: 42.6s	remaining: 7m 21s
# 44:	learn: 0.9424723	test: 0.8883016	best: 0.8883016 (44)	total: 43.5s	remaining: 7m 20s
# 45:	learn: 0.9373420	test: 0.8863080	best: 0.8863080 (45)	total: 44.4s	remaining: 7m 18s
# 46:	learn: 0.9307604	test: 0.8833550	best: 0.8833550 (46)	total: 45.6s	remaining: 7m 19s
# 47:	learn: 0.9272424	test: 0.8814990	best: 0.8814990 (47)	total: 46.5s	remaining: 7m 17s
# 48:	learn: 0.9243783	test: 0.8802048	best: 0.8802048 (48)	total: 47.3s	remaining: 7m 15s
# 49:	learn: 0.9200242	test: 0.8783628	best: 0.8783628 (49)	total: 48.3s	remaining: 7m 14s
# 50:	learn: 0.9150096	test: 0.8785191	best: 0.8783628 (49)	total: 49.2s	remaining: 7m 12s
# 51:	learn: 0.9110243	test: 0.8802214	best: 0.8783628 (49)	total: 50s	remaining: 7m 11s
# 52:	learn: 0.9070363	test: 0.8771905	best: 0.8771905 (52)	total: 51s	remaining: 7m 9s
# 53:	learn: 0.9037488	test: 0.8760999	best: 0.8760999 (53)	total: 51.9s	remaining: 7m 8s
# 54:	learn: 0.9005132	test: 0.8750359	best: 0.8750359 (54)	total: 53.1s	remaining: 7m 9s
# 55:	learn: 0.8978742	test: 0.8739401	best: 0.8739401 (55)	total: 54.2s	remaining: 7m 9s
# 56:	learn: 0.8952979	test: 0.8736289	best: 0.8736289 (56)	total: 55s	remaining: 7m 7s
# 57:	learn: 0.8925754	test: 0.8729784	best: 0.8729784 (57)	total: 55.9s	remaining: 7m 6s
# 58:	learn: 0.8889468	test: 0.8712109	best: 0.8712109 (58)	total: 57s	remaining: 7m 5s
# 59:	learn: 0.8855260	test: 0.8685593	best: 0.8685593 (59)	total: 58.2s	remaining: 7m 6s
# 60:	learn: 0.8825569	test: 0.8678869	best: 0.8678869 (60)	total: 59.3s	remaining: 7m 7s
# 61:	learn: 0.8786419	test: 0.8660395	best: 0.8660395 (61)	total: 1m	remaining: 7m 5s
# 62:	learn: 0.8753922	test: 0.8646213	best: 0.8646213 (62)	total: 1m 1s	remaining: 7m 5s
# 63:	learn: 0.8724729	test: 0.8620813	best: 0.8620813 (63)	total: 1m 2s	remaining: 7m 3s
# 64:	learn: 0.8697638	test: 0.8608196	best: 0.8608196 (64)	total: 1m 3s	remaining: 7m 3s
# 65:	learn: 0.8676088	test: 0.8600768	best: 0.8600768 (65)	total: 1m 4s	remaining: 7m 2s
# 66:	learn: 0.8651383	test: 0.8582535	best: 0.8582535 (66)	total: 1m 5s	remaining: 7m
# 67:	learn: 0.8608145	test: 0.8594040	best: 0.8582535 (66)	total: 1m 6s	remaining: 7m
# 68:	learn: 0.8577604	test: 0.8587096	best: 0.8582535 (66)	total: 1m 7s	remaining: 7m
# 69:	learn: 0.8553180	test: 0.8573765	best: 0.8573765 (69)	total: 1m 8s	remaining: 6m 59s
# 70:	learn: 0.8532992	test: 0.8566687	best: 0.8566687 (70)	total: 1m 9s	remaining: 6m 58s
# 71:	learn: 0.8509564	test: 0.8565204	best: 0.8565204 (71)	total: 1m 10s	remaining: 6m 58s
# 72:	learn: 0.8479679	test: 0.8585834	best: 0.8565204 (71)	total: 1m 11s	remaining: 6m 56s
# 73:	learn: 0.8433684	test: 0.8573934	best: 0.8565204 (71)	total: 1m 12s	remaining: 6m 55s
# 74:	learn: 0.8421018	test: 0.8569682	best: 0.8565204 (71)	total: 1m 13s	remaining: 6m 53s
# 75:	learn: 0.8390949	test: 0.8556103	best: 0.8556103 (75)	total: 1m 13s	remaining: 6m 52s
# 76:	learn: 0.8358178	test: 0.8520042	best: 0.8520042 (76)	total: 1m 15s	remaining: 6m 52s
# 77:	learn: 0.8336850	test: 0.8504992	best: 0.8504992 (77)	total: 1m 16s	remaining: 6m 52s
# 78:	learn: 0.8311958	test: 0.8523868	best: 0.8504992 (77)	total: 1m 17s	remaining: 6m 50s
# 79:	learn: 0.8294979	test: 0.8519724	best: 0.8504992 (77)	total: 1m 17s	remaining: 6m 49s
# 80:	learn: 0.8271676	test: 0.8507589	best: 0.8504992 (77)	total: 1m 18s	remaining: 6m 48s
# 81:	learn: 0.8239852	test: 0.8489607	best: 0.8489607 (81)	total: 1m 20s	remaining: 6m 47s
# 82:	learn: 0.8217330	test: 0.8480208	best: 0.8480208 (82)	total: 1m 21s	remaining: 6m 47s
# 83:	learn: 0.8201072	test: 0.8480710	best: 0.8480208 (82)	total: 1m 22s	remaining: 6m 46s
# 84:	learn: 0.8171889	test: 0.8453174	best: 0.8453174 (84)	total: 1m 23s	remaining: 6m 45s
# 85:	learn: 0.8153506	test: 0.8452121	best: 0.8452121 (85)	total: 1m 24s	remaining: 6m 44s
# 86:	learn: 0.8137484	test: 0.8480427	best: 0.8452121 (85)	total: 1m 24s	remaining: 6m 43s
# 87:	learn: 0.8117896	test: 0.8471854	best: 0.8452121 (85)	total: 1m 26s	remaining: 6m 42s
# 88:	learn: 0.8096657	test: 0.8465255	best: 0.8452121 (85)	total: 1m 27s	remaining: 6m 41s
# 89:	learn: 0.8078617	test: 0.8446808	best: 0.8446808 (89)	total: 1m 27s	remaining: 6m 40s
# 90:	learn: 0.8057877	test: 0.8438328	best: 0.8438328 (90)	total: 1m 29s	remaining: 6m 40s
# 91:	learn: 0.8042070	test: 0.8421926	best: 0.8421926 (91)	total: 1m 29s	remaining: 6m 38s
# 92:	learn: 0.8027068	test: 0.8415190	best: 0.8415190 (92)	total: 1m 31s	remaining: 6m 38s
# 93:	learn: 0.8007019	test: 0.8440598	best: 0.8415190 (92)	total: 1m 31s	remaining: 6m 37s
# 94:	learn: 0.7989108	test: 0.8435076	best: 0.8415190 (92)	total: 1m 32s	remaining: 6m 36s
# 95:	learn: 0.7967991	test: 0.8461434	best: 0.8415190 (92)	total: 1m 33s	remaining: 6m 34s
# 96:	learn: 0.7952430	test: 0.8452527	best: 0.8415190 (92)	total: 1m 34s	remaining: 6m 33s
# 97:	learn: 0.7936332	test: 0.8441818	best: 0.8415190 (92)	total: 1m 35s	remaining: 6m 33s
# 98:	learn: 0.7919985	test: 0.8430154	best: 0.8415190 (92)	total: 1m 36s	remaining: 6m 32s
# 99:	learn: 0.7900914	test: 0.8419697	best: 0.8415190 (92)	total: 1m 37s	remaining: 6m 30s
# 100:	learn: 0.7883936	test: 0.8417187	best: 0.8415190 (92)	total: 1m 38s	remaining: 6m 29s
# 101:	learn: 0.7871583	test: 0.8409098	best: 0.8409098 (101)	total: 1m 39s	remaining: 6m 28s
# 102:	learn: 0.7857447	test: 0.8406016	best: 0.8406016 (102)	total: 1m 40s	remaining: 6m 27s
# 103:	learn: 0.7839652	test: 0.8405653	best: 0.8405653 (103)	total: 1m 41s	remaining: 6m 26s
# 104:	learn: 0.7817174	test: 0.8390969	best: 0.8390969 (104)	total: 1m 42s	remaining: 6m 25s
# 105:	learn: 0.7795887	test: 0.8383851	best: 0.8383851 (105)	total: 1m 43s	remaining: 6m 24s
# 106:	learn: 0.7782126	test: 0.8381706	best: 0.8381706 (106)	total: 1m 44s	remaining: 6m 23s
# 107:	learn: 0.7774079	test: 0.8374474	best: 0.8374474 (107)	total: 1m 45s	remaining: 6m 21s
# 108:	learn: 0.7763649	test: 0.8372608	best: 0.8372608 (108)	total: 1m 46s	remaining: 6m 20s
# 109:	learn: 0.7747711	test: 0.8366893	best: 0.8366893 (109)	total: 1m 47s	remaining: 6m 19s
# 110:	learn: 0.7734557	test: 0.8360187	best: 0.8360187 (110)	total: 1m 48s	remaining: 6m 19s
# 111:	learn: 0.7721189	test: 0.8358842	best: 0.8358842 (111)	total: 1m 49s	remaining: 6m 18s
# 112:	learn: 0.7709180	test: 0.8356915	best: 0.8356915 (112)	total: 1m 50s	remaining: 6m 17s
# 113:	learn: 0.7691855	test: 0.8351378	best: 0.8351378 (113)	total: 1m 51s	remaining: 6m 16s
# 114:	learn: 0.7669486	test: 0.8369474	best: 0.8351378 (113)	total: 1m 52s	remaining: 6m 16s
# 115:	learn: 0.7648538	test: 0.8363680	best: 0.8351378 (113)	total: 1m 53s	remaining: 6m 15s
# 116:	learn: 0.7641197	test: 0.8360565	best: 0.8351378 (113)	total: 1m 54s	remaining: 6m 14s
# 117:	learn: 0.7629713	test: 0.8353393	best: 0.8351378 (113)	total: 1m 55s	remaining: 6m 13s
# 118:	learn: 0.7615949	test: 0.8344443	best: 0.8344443 (118)	total: 1m 56s	remaining: 6m 12s
# 119:	learn: 0.7599969	test: 0.8303696	best: 0.8303696 (119)	total: 1m 57s	remaining: 6m 11s
# 120:	learn: 0.7584351	test: 0.8298745	best: 0.8298745 (120)	total: 1m 58s	remaining: 6m 10s
# 121:	learn: 0.7578332	test: 0.8297329	best: 0.8297329 (121)	total: 1m 59s	remaining: 6m 8s
# 122:	learn: 0.7565877	test: 0.8289699	best: 0.8289699 (122)	total: 1m 59s	remaining: 6m 7s
# 123:	learn: 0.7556927	test: 0.8287769	best: 0.8287769 (123)	total: 2m	remaining: 6m 6s
# 124:	learn: 0.7541705	test: 0.8276131	best: 0.8276131 (124)	total: 2m 1s	remaining: 6m 5s
# 125:	learn: 0.7531050	test: 0.8276259	best: 0.8276131 (124)	total: 2m 2s	remaining: 6m 4s
# 126:	learn: 0.7518206	test: 0.8273665	best: 0.8273665 (126)	total: 2m 4s	remaining: 6m 4s
# 127:	learn: 0.7508399	test: 0.8271229	best: 0.8271229 (127)	total: 2m 4s	remaining: 6m 3s
# 128:	learn: 0.7497943	test: 0.8263141	best: 0.8263141 (128)	total: 2m 5s	remaining: 6m 1s
# 129:	learn: 0.7491861	test: 0.8260505	best: 0.8260505 (129)	total: 2m 6s	remaining: 6m
# 130:	learn: 0.7484604	test: 0.8260444	best: 0.8260444 (130)	total: 2m 7s	remaining: 5m 59s
# 131:	learn: 0.7470259	test: 0.8254427	best: 0.8254427 (131)	total: 2m 8s	remaining: 5m 58s
# 132:	learn: 0.7455496	test: 0.8245581	best: 0.8245581 (132)	total: 2m 9s	remaining: 5m 57s
# 133:	learn: 0.7448712	test: 0.8242683	best: 0.8242683 (133)	total: 2m 10s	remaining: 5m 55s
# 134:	learn: 0.7442736	test: 0.8238543	best: 0.8238543 (134)	total: 2m 11s	remaining: 5m 54s
# 135:	learn: 0.7427345	test: 0.8229582	best: 0.8229582 (135)	total: 2m 12s	remaining: 5m 53s
# 136:	learn: 0.7413451	test: 0.8222383	best: 0.8222383 (136)	total: 2m 13s	remaining: 5m 53s
# 137:	learn: 0.7407793	test: 0.8220928	best: 0.8220928 (137)	total: 2m 14s	remaining: 5m 51s
# 138:	learn: 0.7398900	test: 0.8218486	best: 0.8218486 (138)	total: 2m 14s	remaining: 5m 50s
# 139:	learn: 0.7390643	test: 0.8219605	best: 0.8218486 (138)	total: 2m 15s	remaining: 5m 49s
# 140:	learn: 0.7377897	test: 0.8211221	best: 0.8211221 (140)	total: 2m 16s	remaining: 5m 48s
# 141:	learn: 0.7366814	test: 0.8207345	best: 0.8207345 (141)	total: 2m 17s	remaining: 5m 47s
# 142:	learn: 0.7356678	test: 0.8230866	best: 0.8207345 (141)	total: 2m 18s	remaining: 5m 46s
# 143:	learn: 0.7348991	test: 0.8230650	best: 0.8207345 (141)	total: 2m 19s	remaining: 5m 44s
# 144:	learn: 0.7338357	test: 0.8225851	best: 0.8207345 (141)	total: 2m 20s	remaining: 5m 43s
# 145:	learn: 0.7329970	test: 0.8220649	best: 0.8207345 (141)	total: 2m 21s	remaining: 5m 42s
# 146:	learn: 0.7323291	test: 0.8218046	best: 0.8207345 (141)	total: 2m 22s	remaining: 5m 41s
# 147:	learn: 0.7315239	test: 0.8212963	best: 0.8207345 (141)	total: 2m 23s	remaining: 5m 40s
# 148:	learn: 0.7311093	test: 0.8211998	best: 0.8207345 (141)	total: 2m 23s	remaining: 5m 38s
# 149:	learn: 0.7299668	test: 0.8212002	best: 0.8207345 (141)	total: 2m 24s	remaining: 5m 38s
# 150:	learn: 0.7286919	test: 0.8206609	best: 0.8206609 (150)	total: 2m 26s	remaining: 5m 37s
# 151:	learn: 0.7276692	test: 0.8205379	best: 0.8205379 (151)	total: 2m 27s	remaining: 5m 36s
# 152:	learn: 0.7265121	test: 0.8204451	best: 0.8204451 (152)	total: 2m 27s	remaining: 5m 35s
# 153:	learn: 0.7244126	test: 0.8193552	best: 0.8193552 (153)	total: 2m 29s	remaining: 5m 35s
# 154:	learn: 0.7234369	test: 0.8190031	best: 0.8190031 (154)	total: 2m 30s	remaining: 5m 34s
# 155:	learn: 0.7210588	test: 0.8167435	best: 0.8167435 (155)	total: 2m 31s	remaining: 5m 33s
# 156:	learn: 0.7200426	test: 0.8160190	best: 0.8160190 (156)	total: 2m 32s	remaining: 5m 32s
# 157:	learn: 0.7189296	test: 0.8156064	best: 0.8156064 (157)	total: 2m 33s	remaining: 5m 31s
# 158:	learn: 0.7179613	test: 0.8144930	best: 0.8144930 (158)	total: 2m 34s	remaining: 5m 30s
# 159:	learn: 0.7166748	test: 0.8144457	best: 0.8144457 (159)	total: 2m 35s	remaining: 5m 29s
# 160:	learn: 0.7160915	test: 0.8143088	best: 0.8143088 (160)	total: 2m 36s	remaining: 5m 28s
# 161:	learn: 0.7152115	test: 0.8137520	best: 0.8137520 (161)	total: 2m 37s	remaining: 5m 27s
# 162:	learn: 0.7144396	test: 0.8133695	best: 0.8133695 (162)	total: 2m 37s	remaining: 5m 26s
# 163:	learn: 0.7136062	test: 0.8132132	best: 0.8132132 (163)	total: 2m 38s	remaining: 5m 25s
# 164:	learn: 0.7123084	test: 0.8125731	best: 0.8125731 (164)	total: 2m 40s	remaining: 5m 24s
# 165:	learn: 0.7113797	test: 0.8155664	best: 0.8125731 (164)	total: 2m 40s	remaining: 5m 23s
# 166:	learn: 0.7108263	test: 0.8154001	best: 0.8125731 (164)	total: 2m 41s	remaining: 5m 22s
# 167:	learn: 0.7103009	test: 0.8151857	best: 0.8125731 (164)	total: 2m 42s	remaining: 5m 21s
# 168:	learn: 0.7088582	test: 0.8151177	best: 0.8125731 (164)	total: 2m 43s	remaining: 5m 20s
# 169:	learn: 0.7076419	test: 0.8144891	best: 0.8125731 (164)	total: 2m 44s	remaining: 5m 19s
# 170:	learn: 0.7072577	test: 0.8145958	best: 0.8125731 (164)	total: 2m 45s	remaining: 5m 17s
# 171:	learn: 0.7054979	test: 0.8129040	best: 0.8125731 (164)	total: 2m 46s	remaining: 5m 16s
# 172:	learn: 0.7041144	test: 0.8121081	best: 0.8121081 (172)	total: 2m 47s	remaining: 5m 16s
# 173:	learn: 0.7030319	test: 0.8117557	best: 0.8117557 (173)	total: 2m 48s	remaining: 5m 14s
# 174:	learn: 0.7024615	test: 0.8119580	best: 0.8117557 (173)	total: 2m 49s	remaining: 5m 13s
# 175:	learn: 0.7018100	test: 0.8120773	best: 0.8117557 (173)	total: 2m 49s	remaining: 5m 12s
# 176:	learn: 0.7011131	test: 0.8121260	best: 0.8117557 (173)	total: 2m 50s	remaining: 5m 11s
# 177:	learn: 0.7006020	test: 0.8115377	best: 0.8115377 (177)	total: 2m 51s	remaining: 5m 10s
# 178:	learn: 0.7001681	test: 0.8114805	best: 0.8114805 (178)	total: 2m 52s	remaining: 5m 9s
# 179:	learn: 0.6995366	test: 0.8117013	best: 0.8114805 (178)	total: 2m 53s	remaining: 5m 8s
# 180:	learn: 0.6986556	test: 0.8114269	best: 0.8114269 (180)	total: 2m 54s	remaining: 5m 7s
# 181:	learn: 0.6978855	test: 0.8107701	best: 0.8107701 (181)	total: 2m 55s	remaining: 5m 6s
# 182:	learn: 0.6967918	test: 0.8098783	best: 0.8098783 (182)	total: 2m 56s	remaining: 5m 5s
# 183:	learn: 0.6956223	test: 0.8096511	best: 0.8096511 (183)	total: 2m 57s	remaining: 5m 4s
# 184:	learn: 0.6947521	test: 0.8125824	best: 0.8096511 (183)	total: 2m 58s	remaining: 5m 3s
# 185:	learn: 0.6938833	test: 0.8122461	best: 0.8096511 (183)	total: 2m 59s	remaining: 5m 2s
# 186:	learn: 0.6931193	test: 0.8120307	best: 0.8096511 (183)	total: 3m	remaining: 5m 1s
# 187:	learn: 0.6926351	test: 0.8122830	best: 0.8096511 (183)	total: 3m 1s	remaining: 5m
# 188:	learn: 0.6919594	test: 0.8122713	best: 0.8096511 (183)	total: 3m 1s	remaining: 4m 59s
# 189:	learn: 0.6909326	test: 0.8110619	best: 0.8096511 (183)	total: 3m 2s	remaining: 4m 58s
# 190:	learn: 0.6899846	test: 0.8103716	best: 0.8096511 (183)	total: 3m 3s	remaining: 4m 57s
# 191:	learn: 0.6891975	test: 0.8098768	best: 0.8096511 (183)	total: 3m 4s	remaining: 4m 56s
# 192:	learn: 0.6872830	test: 0.8076830	best: 0.8076830 (192)	total: 3m 5s	remaining: 4m 55s
# 193:	learn: 0.6867517	test: 0.8073832	best: 0.8073832 (193)	total: 3m 6s	remaining: 4m 54s
# 194:	learn: 0.6861606	test: 0.8072091	best: 0.8072091 (194)	total: 3m 7s	remaining: 4m 53s
# 195:	learn: 0.6854606	test: 0.8072096	best: 0.8072091 (194)	total: 3m 8s	remaining: 4m 52s
# 196:	learn: 0.6849015	test: 0.8070242	best: 0.8070242 (196)	total: 3m 9s	remaining: 4m 51s
# 197:	learn: 0.6843166	test: 0.8068366	best: 0.8068366 (197)	total: 3m 10s	remaining: 4m 50s
# 198:	learn: 0.6834306	test: 0.8064466	best: 0.8064466 (198)	total: 3m 11s	remaining: 4m 49s
# 199:	learn: 0.6829135	test: 0.8064399	best: 0.8064399 (199)	total: 3m 12s	remaining: 4m 48s
# 200:	learn: 0.6817289	test: 0.8058893	best: 0.8058893 (200)	total: 3m 13s	remaining: 4m 47s
# 201:	learn: 0.6811994	test: 0.8057621	best: 0.8057621 (201)	total: 3m 14s	remaining: 4m 46s
# 202:	learn: 0.6808812	test: 0.8057132	best: 0.8057132 (202)	total: 3m 15s	remaining: 4m 45s
# 203:	learn: 0.6797208	test: 0.8042611	best: 0.8042611 (203)	total: 3m 16s	remaining: 4m 44s
# 204:	learn: 0.6781564	test: 0.8030004	best: 0.8030004 (204)	total: 3m 17s	remaining: 4m 43s
# 205:	learn: 0.6775466	test: 0.8031508	best: 0.8030004 (204)	total: 3m 17s	remaining: 4m 42s
# 206:	learn: 0.6766611	test: 0.8030024	best: 0.8030004 (204)	total: 3m 18s	remaining: 4m 41s
# 207:	learn: 0.6762867	test: 0.8031194	best: 0.8030004 (204)	total: 3m 19s	remaining: 4m 40s
# 208:	learn: 0.6756617	test: 0.8028502	best: 0.8028502 (208)	total: 3m 20s	remaining: 4m 39s
# 209:	learn: 0.6754110	test: 0.8027925	best: 0.8027925 (209)	total: 3m 21s	remaining: 4m 38s
# 210:	learn: 0.6745055	test: 0.8026465	best: 0.8026465 (210)	total: 3m 22s	remaining: 4m 36s
# 211:	learn: 0.6738611	test: 0.8055604	best: 0.8026465 (210)	total: 3m 23s	remaining: 4m 35s
# 212:	learn: 0.6732506	test: 0.8054699	best: 0.8026465 (210)	total: 3m 23s	remaining: 4m 34s
# 213:	learn: 0.6724565	test: 0.8050935	best: 0.8026465 (210)	total: 3m 24s	remaining: 4m 33s
# 214:	learn: 0.6720006	test: 0.8049264	best: 0.8026465 (210)	total: 3m 25s	remaining: 4m 32s
# 215:	learn: 0.6715101	test: 0.8046232	best: 0.8026465 (210)	total: 3m 26s	remaining: 4m 31s
# 216:	learn: 0.6707361	test: 0.8040351	best: 0.8026465 (210)	total: 3m 27s	remaining: 4m 30s
# 217:	learn: 0.6698804	test: 0.8037783	best: 0.8026465 (210)	total: 3m 28s	remaining: 4m 29s
# 218:	learn: 0.6696051	test: 0.8036817	best: 0.8026465 (210)	total: 3m 29s	remaining: 4m 28s
# 219:	learn: 0.6688082	test: 0.8034327	best: 0.8026465 (210)	total: 3m 30s	remaining: 4m 27s
# 220:	learn: 0.6680866	test: 0.8062144	best: 0.8026465 (210)	total: 3m 31s	remaining: 4m 26s
# 221:	learn: 0.6676651	test: 0.8057969	best: 0.8026465 (210)	total: 3m 31s	remaining: 4m 25s
# 222:	learn: 0.6671605	test: 0.8057006	best: 0.8026465 (210)	total: 3m 32s	remaining: 4m 24s
# 223:	learn: 0.6668041	test: 0.8055095	best: 0.8026465 (210)	total: 3m 33s	remaining: 4m 23s
# 224:	learn: 0.6662833	test: 0.8050612	best: 0.8026465 (210)	total: 3m 34s	remaining: 4m 22s
# 225:	learn: 0.6653386	test: 0.8044804	best: 0.8026465 (210)	total: 3m 35s	remaining: 4m 21s
# 226:	learn: 0.6643352	test: 0.8043037	best: 0.8026465 (210)	total: 3m 36s	remaining: 4m 20s
# 227:	learn: 0.6636742	test: 0.8037934	best: 0.8026465 (210)	total: 3m 37s	remaining: 4m 19s
# 228:	learn: 0.6633901	test: 0.8038414	best: 0.8026465 (210)	total: 3m 38s	remaining: 4m 18s
# 229:	learn: 0.6629211	test: 0.8041600	best: 0.8026465 (210)	total: 3m 39s	remaining: 4m 17s
# 230:	learn: 0.6623735	test: 0.8038333	best: 0.8026465 (210)	total: 3m 40s	remaining: 4m 16s
# bestTest = 0.8026465289
# bestIteration = 210
# Shrink model to first 211 iterations.
# Count: 200000
# Top 1: 0.77411
# Top 2: 0.911625
# Top 3: 0.934085
# Top 4: 0.945155
# Top 5: 0.955205
# Top1 1: 0.800155
# Mean: 3.657995

# %%
top1 = []
top5 = []
mean = []

for _ in range(100):
    test_indexes = np.random.choice(len(X_test), 20000)
    test_X = X_test[test_indexes]
    test_y = y_test[test_indexes]
    predicted = model.predict(test_X)
    metric = Metric(predicted, test_y)
    print(metric.top_i(1))
    top1.append(metric.top_i(1))
    top5.append(metric.top_i(5))
    mean.append(metric.mean)
# Out:
# 0.76935
# 0.7693
# 0.77245
# 0.77275
# 0.77005
# 0.7706
# 0.7725
# 0.7738
# 0.778
# 0.77655
# 0.77125
# 0.7741
# 0.7774
# 0.77285
# 0.77715
# 0.7718
# 0.7707
# 0.77025
# 0.7736
# 0.7731
# 0.7765
# 0.7753
# 0.7724
# 0.77505
# 0.77205
# 0.7753
# 0.7696
# 0.77165
# 0.77345
# 0.7725
# 0.7732
# 0.7736
# 0.77525
# 0.77265
# 0.775
# 0.7727
# 0.77015
# 0.76945
# 0.77075
# 0.77405
# 0.768
# 0.76985
# 0.7728
# 0.7689
# 0.76825
# 0.7718
# 0.77285
# 0.77415
# 0.76935
# 0.7685
# 0.7707
# 0.77155
# 0.77455
# 0.7717
# 0.77085
# 0.774
# 0.77025
# 0.7699
# 0.7714
# 0.77405
# 0.7786
# 0.7728
# 0.7737
# 0.77035
# 0.76625
# 0.76615
# 0.7729
# 0.77065
# 0.77355
# 0.7718
# 0.77645
# 0.77125
# 0.76925
# 0.7743
# 0.77225
# 0.7748
# 0.77385
# 0.7733
# 0.77575
# 0.7689
# 0.7711
# 0.7664
# 0.7757
# 0.7726
# 0.77585
# 0.77495
# 0.7689
# 0.77165
# 0.76635
# 0.77235
# 0.77115
# 0.77425
# 0.77475
# 0.7685
# 0.7706
# 0.7703
# 0.7693
# 0.76875
# 0.7725
# 0.77055

# %%
print(np.min(top1))
print(np.max(top1))
print(np.mean(top1))
print()

print(np.min(top5))
print(np.max(top5))
print(np.mean(top5))
print()

print(np.min(mean))
print(np.max(mean))
print(np.mean(mean))
print()
# Out:
# 0.76615
# 0.7786
# 0.772149
#
# 0.9496
# 0.95675
# 0.9532459999999999
#
# 3.7667
# 4.55485
# 4.077229

# %%
baseline = Baseline()
calculate_and_print(X_train, X_test, y_train, y_test, baseline)
# Out:
# Baseline
# Count: 200000
# Top 1: 0.63683
# Top 2: 0.78531
# Top 3: 0.856845
# Top 4: 0.86928
# Top 5: 0.889555
# Top1 1: 0.653615
# Mean: 6.20635

# %%
top1_baseline = []
top5_baseline = []
mean_baseline = []
top1 = []
top5 = []
mean = []

for _ in range(100):
    test_indexes = np.random.choice(len(X_test), 20000)
    test_X = X_test[test_indexes]
    test_y = y_test[test_indexes]
    predicted = model.predict(test_X)
    metric = Metric(predicted, test_y)
    print(metric.mean)
    top1.append(metric.top_i(1))
    top5.append(metric.top_i(5))
    mean.append(metric.mean)
    predicted = baseline.predict(test_X)
    metric = Metric(predicted, test_y)
    print(metric.mean)
    top1_baseline.append(metric.top_i(1))
    top5_baseline.append(metric.top_i(5))
    mean_baseline.append(metric.mean)
# Out:
# 3.3829
# 5.55945
# 3.7648
# 5.9068
# 3.5985
# 5.8749
# 3.6255
# 5.83575
# 3.7837
# 6.06735
# 3.73115
# 5.85795
# 3.88775
# 5.89795
# 3.6371
# 5.6898
# 3.7215
# 5.9152
# 3.483
# 5.7621
# 3.7399
# 5.80455
# 3.62365
# 5.8675
# 3.71185
# 5.93185
# 3.83585
# 5.88895
# 3.7591
# 5.9235
# 3.65545
# 5.86305
# 3.86985
# 5.9291
# 3.65935
# 5.78605
# 3.526
# 5.70625
# 3.79325
# 5.88505
# 3.6475
# 5.80625
# 3.5905
# 5.795
# 3.7049
# 5.7995
# 3.7015
# 6.08215
# 3.7081
# 5.90395
# 3.6609
# 5.77195
# 3.56685
# 5.79885
# 3.6507
# 5.8057
# 3.74585
# 5.85585
# 3.9991
# 6.10025
# 3.7478
# 5.98295
# 3.61575
# 5.7564
# 3.61625
# 5.8378
# 3.59665
# 5.85155
# 3.9469
# 5.98805
# 3.62795
# 5.8766
# 3.53655
# 5.8032
# 3.48815
# 5.6283
# 3.5851
# 5.73245
# 3.8029
# 5.96765
# 3.5964
# 5.72085
# 3.7038
# 5.75705
# 3.46445
# 5.7726
# 3.7272
# 5.78785
# 3.7117
# 5.73465
# 3.74065
# 5.8923
# 3.9311
# 6.15395
# 3.71235
# 5.94205
# 3.78575
# 6.0679
# 3.3908
# 5.55325
# 3.5126
# 5.6097
# 3.66875
# 5.7649
# 3.85195
# 5.99445
# 3.6169
# 5.8383
# 3.5379
# 5.7118
# 3.53605
# 5.80515
# 3.525
# 5.70125
# 3.5969
# 5.7241
# 3.69625
# 5.93235
# 3.7129
# 5.8992
# 3.64055
# 6.023
# 3.67895
# 5.9852
# 3.56585
# 5.71505
# 3.8244
# 5.9664
# 3.7661
# 5.89205
# 3.78385
# 5.8507
# 3.4511
# 5.67865
# 3.52725
# 5.72515
# 3.8155
# 5.977
# 3.77015
# 5.96825
# 3.6461
# 5.8651
# 3.5922
# 5.77495
# 3.62825
# 5.88945
# 3.77745
# 5.8906
# 3.75745
# 5.8862
# 3.80455
# 6.0744
# 3.46085
# 5.59945
# 3.82275
# 5.9931
# 3.59255
# 5.843
# 3.5217
# 5.6964
# 3.68005
# 5.8088
# 3.59635
# 5.7353
# 3.5794
# 5.73925
# 3.7415
# 5.8525
# 3.656
# 5.85005
# 3.4994
# 5.7353
# 3.6637
# 5.8563
# 3.756
# 5.98255
# 3.49545
# 5.56515
# 3.61165
# 5.7707
# 3.4638
# 5.6261
# 3.57405
# 5.70845
# 3.6487
# 5.8281
# 3.83555
# 6.0842
# 3.63465
# 5.8667
# 3.78645
# 5.7928
# 3.4609
# 5.7803
# 3.5841
# 5.8256
# 3.7048
# 5.93335
# 3.7756
# 5.95335

# %%
print(np.min(top1))
print(np.max(top1))
print(np.mean(top1))
print()

print(np.min(top1_baseline))
print(np.max(top1_baseline))
print(np.mean(top1_baseline))
print()

print(np.min(top5))
print(np.max(top5))
print(np.mean(top5))
print()

print(np.min(top5_baseline))
print(np.max(top5_baseline))
print(np.mean(top5_baseline))
print()

print(np.min(mean))
print(np.max(mean))
print(np.mean(mean))
print()

print(np.min(mean_baseline))
print(np.max(mean_baseline))
print(np.mean(mean_baseline))
print()
# Out:
# 0.7679
# 0.78045
# 0.7740835000000003
#
# 0.61145
# 0.6271
# 0.619912
#
# 0.95225
# 0.95915
# 0.9551505
#
# 0.80015
# 0.81205
# 0.806124
#
# 3.3829
# 3.9991
# 3.665250999999999
#
# 5.55325
# 6.15395
# 5.840501000000001

# %%
def interval(l, percent):
    x = int(round(len(l) / 100 * percent))
    return sorted(l)[x:-x]

top1_interval = interval(top1, 5)
top1_baseline_interval = interval(top1_baseline, 5)
top5_interval = interval(top5, 5)
top5_baseline_interval = interval(top5_baseline, 5)
mean_interval = interval(mean, 5)
mean_baseline_interval = interval(mean_baseline, 5)

# %%
print(np.min(top1_interval))
print(np.max(top1_interval))
print(np.mean(top1_interval))
print()

print(np.min(top1_baseline_interval))
print(np.max(top1_baseline_interval))
print(np.mean(top1_baseline_interval))
print()

print(np.min(top5_interval))
print(np.max(top5_interval))
print(np.mean(top5_interval))
print()

print(np.min(top5_baseline_interval))
print(np.max(top5_baseline_interval))
print(np.mean(top5_baseline_interval))
print()

print(np.min(mean_interval))
print(np.max(mean_interval))
print(np.mean(mean_interval))
print()

print(np.min(mean_baseline_interval))
print(np.max(mean_baseline_interval))
print(np.mean(mean_baseline_interval))
print()
# Out:
# 0.76975
# 0.77895
# 0.7740783333333334
#
# 0.61445
# 0.6256
# 0.619965
#
# 0.95325
# 0.9578
# 0.9550966666666667
#
# 0.80165
# 0.81045
# 0.8061355555555555
#
# 3.4638
# 3.85195
# 3.6638205555555556
#
# 5.6261
# 6.0679
# 5.840757222222222
