# %% [markdown]
# # Compare models with annotations split by target type

# %%
from utils.usage_loader import target_types
from sklearn.model_selection import train_test_split
from metric.calculate import calculate
import pickle
from models.linear import SVM, LinearSVM, LogisticReg
from models.tree import CatBoost, RandomForest, GradientBoosting
from models.baseline import Baseline
import matplotlib.pyplot as plt
from collections import Counter
import warnings

# %%
with open('data/usage_loader.pickle', 'rb') as f:
    usage_loader = pickle.load(f)

# %% [markdown]
# ## Without polynomial features

# %%
def plot(models_names, metric1, metric1_label, metric2, metric2_label, title, reverse=False):
    metric1, metric2, models_names = zip(*sorted(zip(metric1, metric2, models_names), reverse=reverse))
    plt.figure(figsize=(15, 9))
    names = []
    for name in models_names:
        names.append(f'{name} {metric1_label}')
        names.append(f'{name} {metric2_label}')

    pl = plt.barh(list(range(1, 3 * len(metric1) + 1, 3)), metric1, label=metric1_label)
    for bar in pl:
        width = bar.get_width()
        label_y = bar.get_y() + bar.get_height() / 2
        plt.text(width, label_y, s=f'{width}')
    pl = plt.barh(list(range(2, 3 * len(metric1) + 1, 3)), metric2, label=metric2_label)
    for bar in pl:
        width = bar.get_width()
        label_y = bar.get_y() + bar.get_height() / 2
        plt.text(width, label_y, s=f'{width}')
    plt.title(title)
    idx = sorted(list(range(1, 3 * len(metric1) + 1, 3)) + list(range(2, 3 * len(metric1) + 1, 3)))
    plt.yticks(idx, names)
    plt.show()


with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for target_type in usage_loader.usages_by_target:
        models_names = []
        top1 = []
        top5 = []
        mean = []
        top1_poly = []
        top5_poly = []
        mean_poly = []
        train_size = 0.8
        for need_poly in [False, True]:
            X, y, feature_names = usage_loader.load_for_target(target_type,
                                                               size=10000,
                                                               train_fraction=train_size,
                                                               need_polynomial=need_poly,
                                                               state=123)
            if len(X) < 4 or len(Counter(y)) == 1:
                continue
            X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=train_size, shuffle=False)
            print(len(X))
            print(len(X_train))
            print(len(X[0]))
            print(target_type)
            models = [Baseline(), CatBoost(task_type='GPU'), RandomForest(), SVM(), LinearSVM(), LogisticReg()]
            for model in models:
                print(model.name)
                metric = calculate(X_train, X_test, y_train, y_test, model)
                if not need_poly:
                    models_names.append(model.name)
                    top1.append(metric.top_i(1))
                    top5.append(metric.top_i(5))
                    mean.append(metric.mean)
                else:
                    top1_poly.append(metric.top_i(1))
                    top5_poly.append(metric.top_i(5))
                    mean_poly.append(metric.mean)
        plot(models_names, top1, 'no poly', top1_poly, 'poly', f'Top 1 {target_type}, test size = {len(X_test)}')
        plot(models_names, top5, 'no poly', top5_poly, 'poly', f'Top 5 {target_type}, test size = {len(X_test)}')
        plot(models_names, mean, 'no poly', mean_poly, 'poly',
             f'Mean position {target_type}, test size = {len(X_test)}', reverse=True)
# Out:
# 10000
# 8000
# 492
# Field
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 492
# 184
# 17020
# 1392
# 10000
# 8000
# 1392
# Field
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 10000
# 8000
# 471
# Type
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 471
# 151
# 11476
# 960
# 10000
# 8000
# 960
# Type
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 10000
# 8000
# 578
# Method
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 578
# 244
# 29890
# 3230
# 10000
# 8000
# 3230
# Method
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 10000
# 8000
# 547
# Parameter
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 547
# 226
# 25651
# 3047
# 10000
# 8000
# 3047
# Parameter
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2745
# 2196
# 497
# LocalVariable
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 497
# 237
# 28203
# 6684
# 2745
# 2196
# 6684
# LocalVariable
# Baseline
# CatBoost
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 788
# 630
# 374
# Constructor
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# 374
# 294
# 43365
# 2611
# 788
# 630
# 2611
# Constructor
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 434
# 347
# 291
# AnnotationType
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# 291
# 122
# 7503
# 370
# 434
# 347
# 370
# AnnotationType
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# 10000
# 8000
# 525
# TypeUse
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 525
# 295
# 43660
# 5900
# 10000
# 8000
# 5900
# TypeUse
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 79
# 63
# 88
# Package
# Baseline
# CatBoost

# %%
def plot(models_names, metric1, metric1_label, metric2, metric2_label, title, reverse=False):
    metric1, metric2, models_names = zip(*sorted(zip(metric1, metric2, models_names), reverse=reverse))
    plt.figure(figsize=(15, 9))
    names = []
    for name in models_names:
        names.append(f'{name} {metric1_label}')
        names.append(f'{name} {metric2_label}')

    pl = plt.barh(list(range(1, 3 * len(metric1) + 1, 3)), metric1, label=metric1_label)
    for bar in pl:
        width = bar.get_width()
        label_y = bar.get_y() + bar.get_height() / 2
        plt.text(width, label_y, s=f'{width}')
    pl = plt.barh(list(range(2, 3 * len(metric1) + 1, 3)), metric2, label=metric2_label)
    for bar in pl:
        width = bar.get_width()
        label_y = bar.get_y() + bar.get_height() / 2
        plt.text(width, label_y, s=f'{width}')
    plt.title(title)
    idx = sorted(list(range(1, 3 * len(metric1) + 1, 3)) + list(range(2, 3 * len(metric1) + 1, 3)))
    plt.yticks(idx, names)
    plt.show()


with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    models_names = []
    top1 = []
    top5 = []
    mean = []
    top1_poly = []
    top5_poly = []
    mean_poly = []
    train_size = 0.8
    for need_poly in [False, True]:
        X, y, feature_names = usage_loader.load(size=10000,
                                                train_fraction=train_size,
                                                need_polynomial=need_poly,
                                                state=123)
        if len(X) < 4 or len(Counter(y)) == 1:
            continue
        X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=train_size, shuffle=False)
        print(len(X))
        print(len(X_train))
        print(len(X[0]))
        models = [Baseline(), CatBoost(task_type='GPU'), RandomForest(), SVM(), LinearSVM(), LogisticReg()]
        for model in models:
            print(model.name)
            metric = calculate(X_train, X_test, y_train, y_test, model)
            if not need_poly:
                models_names.append(model.name)
                top1.append(metric.top_i(1))
                top5.append(metric.top_i(5))
                mean.append(metric.mean)
            else:
                top1_poly.append(metric.top_i(1))
                top5_poly.append(metric.top_i(5))
                mean_poly.append(metric.mean)
    plot(models_names, top1, 'no poly', top1_poly, 'poly', f'Top 1, test size = {len(X_test)}')
    plot(models_names, top5, 'no poly', top5_poly, 'poly', f'Top 5, test size = {len(X_test)}')
    plot(models_names, mean, 'no poly', mean_poly, 'poly',
         f'Mean position, test size = {len(X_test)}', reverse=True)
# Out:
# 10000
# 8000
# 599
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 599
# 237
# 28203
# 3192
# 10000
# 8000
# 3192
# Baseline
# CatBoost
# Random forest
# SVM
# Linear SVM
# Logistic reg
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
